# %%
import pandas as pd
import numpy as np
from os import path

# %%
DATA_DIR = "../../data"
EVAL_DIR = "2021-11-24"

# %%
models = ["logistic_regression", "random_forest", "gradient_boosting", "SVM", "multilayer_perceptron"]
datasets = ["integer_encoded", "pybiomed", "protparam", "bert", "seqvec", "onehot"]

# %%
eval_data = pd.read_csv(path.join(DATA_DIR, "evaluations", EVAL_DIR, "all.csv"), sep="\t")
eval_data.head()
# Out:
#               model_name             data preprocessing        F1       MCC  \
# 0    logistic_regression  integer_encoded          none  0.507463  0.346181
# 1          random_forest  integer_encoded          none  0.228571  0.157435
# 2      gradient_boosting  integer_encoded          none  0.303030  0.300634
# 3                    SVM  integer_encoded          none  0.440678  0.265015
# 4  multilayer_perceptron  integer_encoded          none  0.482759  0.323243
#
#         Acc  Precision    Recall       AUC  \
# 0  0.725000   0.414634  0.653846  0.699264
# 1  0.775000   0.444444  0.153846  0.550327
# 2  0.808333   0.714286  0.192308  0.585516
# 3  0.725000   0.393939  0.500000  0.643617
# 4  0.750000   0.437500  0.538462  0.673486
#
#                                             filename
# 0  ../../data/evaluations/2021-11-24/logistic_reg...
# 1  ../../data/evaluations/2021-11-24/random_fores...
# 2  ../../data/evaluations/2021-11-24/gradient_boo...
# 3  ../../data/evaluations/2021-11-24/SVM_integer_...
# 4  ../../data/evaluations/2021-11-24/multilayer_p...

# %% [markdown]
# # Model statistics

# %%
eval_data.groupby("model_name")[["F1", "MCC"]].mean()
# Out:
#                              F1       MCC
# model_name
# SVM                    0.375161  0.156231
# gradient_boosting      0.140941  0.053224
# logistic_regression    0.403910  0.211975
# multilayer_perceptron  0.259259  0.140437
# random_forest          0.320600  0.145815

# %%
eval_data.groupby("model_name")[["F1", "MCC"]].max()
# Out:
#                              F1       MCC
# model_name
# SVM                    0.558824  0.419850
# gradient_boosting      0.303030  0.300634
# logistic_regression    0.571429  0.437287
# multilayer_perceptron  0.482759  0.325999
# random_forest          0.490566  0.346349

# %%
# lines with maximum F1 score
idx = eval_data.groupby(['model_name'])['F1'].transform(max) == eval_data['F1']
eval_data[idx]
# Out:
#                model_name             data preprocessing        F1       MCC  \
# 2       gradient_boosting  integer_encoded          none  0.303030  0.300634
# 4   multilayer_perceptron  integer_encoded          none  0.482759  0.323243
# 5     logistic_regression         pybiomed          none  0.571429  0.437287
# 18                    SVM             bert          none  0.558824  0.419850
# 28          random_forest         pybiomed          none  0.490566  0.346349
#
#          Acc  Precision    Recall       AUC  \
# 2   0.808333   0.714286  0.192308  0.585516
# 4   0.750000   0.437500  0.538462  0.673486
# 5   0.775000   0.486486  0.692308  0.745090
# 18  0.750000   0.452381  0.730769  0.743044
# 28  0.775000   0.481481  0.500000  0.675532
#
#                                              filename
# 2   ../../data/evaluations/2021-11-24/gradient_boo...
# 4   ../../data/evaluations/2021-11-24/multilayer_p...
# 5   ../../data/evaluations/2021-11-24/logistic_reg...
# 18    ../../data/evaluations/2021-11-24/SVM_bert.json
# 28  ../../data/evaluations/2021-11-24/random_fores...

# %% [markdown]
# # Data statistics

# %%
eval_data.groupby("data")[["F1", "MCC"]].mean()
# Out:
#                        F1       MCC
# data
# bert             0.358883  0.199141
# integer_encoded  0.344144  0.189974
# protparam        0.197279 -0.023862
# pybiomed         0.306221  0.178743
# seqvec           0.330481  0.179894

# %%
eval_data.groupby("data")[["F1", "MCC"]].max()
# Out:
#                        F1       MCC
# data
# bert             0.558824  0.419850
# integer_encoded  0.507463  0.346181
# protparam        0.304147  0.142098
# pybiomed         0.571429  0.437287
# seqvec           0.516129  0.361954

# %%
# lines with maximum F1 score
idx = eval_data.groupby(['data'])['F1'].transform(max) == eval_data['F1']
eval_data[idx]
# Out:
#              model_name             data preprocessing        F1       MCC  \
# 0   logistic_regression  integer_encoded          none  0.507463  0.346181
# 5   logistic_regression         pybiomed          none  0.571429  0.437287
# 18                  SVM             bert          none  0.558824  0.419850
# 20  logistic_regression           seqvec          none  0.516129  0.361954
# 55                  SVM        protparam          none  0.304147 -0.032739
#
#          Acc  Precision    Recall       AUC  \
# 0   0.725000   0.414634  0.653846  0.699264
# 5   0.775000   0.486486  0.692308  0.745090
# 18  0.750000   0.452381  0.730769  0.743044
# 20  0.750000   0.444444  0.615385  0.701309
# 55  0.368201   0.196429  0.673469  0.481472
#
#                                              filename
# 0   ../../data/evaluations/2021-11-24/logistic_reg...
# 5   ../../data/evaluations/2021-11-24/logistic_reg...
# 18    ../../data/evaluations/2021-11-24/SVM_bert.json
# 20  ../../data/evaluations/2021-11-24/logistic_reg...
# 55  ../../data/evaluations/2021-11-24/SVM_protpara...
